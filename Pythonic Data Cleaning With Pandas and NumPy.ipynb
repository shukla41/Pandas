# %%
import pandas as pd
import numpy as np

# %%
### if you want to drop a columns as a list from a dataframe
kill= pd.read_csv(r'C:\Users\shumondal\Desktop\data\PoliceKillingsUS.csv', encoding="windows-1252")
kill
dropcols=['name','date','race','flee','body_camera']
kill.drop(dropcols,inplace=True,axis=1)
kill
# Out:
#         id   manner_of_death       armed   age gender           city state  \
# 0        3              shot         gun  53.0      M        Shelton    WA
# 1        4              shot         gun  47.0      M          Aloha    OR
# 2        5  shot and Tasered     unarmed  23.0      M        Wichita    KS
# 3        8              shot  toy weapon  32.0      M  San Francisco    CA
# 4        9              shot    nail gun  39.0      M          Evans    CO
# ...    ...               ...         ...   ...    ...            ...   ...
# 2530  2822              shot         gun  31.0      M    Kansas City    MO
# 2531  2813              shot     vehicle   NaN      M    Albuquerque    NM
# 2532  2818              shot         gun  48.0      M          Melba    ID
# 2533  2817              shot     vehicle  28.0      M        Oshkosh    WI
# 2534  2815              shot       knife  32.0      M       Brooklyn    NY
#
#       signs_of_mental_illness threat_level
# ...

# %%
### Change the Index of a DataFrame
df=kill.set_index('id')
df1=df.loc[4]
df1
# Out:
# manner_of_death              shot
# armed                         gun
# age                            47
# gender                          M
# city                        Aloha
# state                          OR
# signs_of_mental_illness     False
# threat_level               attack
# Name: 4, dtype: object

# %%
## How to extract specific value from a column usng regex
df
df1=pd.DataFrame(df['manner_of_death'].str.extract(r'([a-z]* [a-z]* \w+)').dropna()).rename(columns={0:"New"})
df2=df1.drop_duplicates()
df2
# Out:
#                  New
# id
# 5   shot and Tasered

# %%
df.loc[53:, 'age'].head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5166             try:
# -> 5167                 return self._searchsorted_monotonic(label, side)
#    5168             except ValueError:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _searchsorted_monotonic(self, label, side)
#    5127
# -> 5128         raise ValueError("index must be monotonic increasing or decreasing")
#    5129
#
# ValueError: index must be monotonic increasing or decreasing
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-ceec5c4d0416> in <module>
# ----> 1 df.loc[53:, 'age'].head(10)
#
# ...

# %%
# Out:
#      manner_of_death       armed   age gender           city state  \
# id
# 3               shot         gun  53.0      M        Shelton    WA
# 4               shot         gun  47.0      M          Aloha    OR
# 5   shot and Tasered     unarmed  23.0      M        Wichita    KS
# 8               shot  toy weapon  32.0      M  San Francisco    CA
# 9               shot    nail gun  39.0      M          Evans    CO
#
#     signs_of_mental_illness threat_level
# id
# 3                      True       attack
# 4                     False       attack
# 5                     False        other
# 8                      True       attack
# 9                     False       attack
